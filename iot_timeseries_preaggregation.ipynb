# %% [markdown]
# # IoT Micro démos
#
# ## Pré-Aggrégation
# Le stockage des données au niveau le plus granulaire n'est généralement nécessaire que pour une durée limitée (par exemple pour une analyse détaillée des erreurs). Pour les visualisations et le stockage à long terme, les agrégations de niveau supérieur sont généralement importantes - en particulier dans les tableaux de bord, il n'y a que quelques pixels disponibles, il n'est pas nécessaire de charger des millions d'enregistrements pour afficher les graphiques.
#
# Les données peuvent facilement être agrégées dans MongoDB, avec l'aide de $merge (disponible depuis MongoDB 4.2), la sortie des agrégations peut être ajoutée aux collections existantes.
#
# Pour que la fusion fonctionne, nous avons besoin d'un index unique dans la (les) collection(s) cible(s).
#
# Dans ce notebook, nous verrons comment faire successivement des aggregations à partir des données brutes à:
# * 1 minute
# * 5 minutes
# * 1 heure
# * 1 journée
#
# ## Initialisation de la démo

# %%
# Installation des librairies non présentes
# !pip3 install dnspython
# Out:
# Collecting dnspython
#   Downloading https://files.pythonhosted.org/packages/f5/2d/ae9e172b4e5e72fa4b3cfc2517f38b602cc9ba31355f9669c502b4e9c458/dnspython-2.1.0-py3-none-any.whl (241kB)
#      |████████████████████████████████| 245kB 5.7MB/s
# Installing collected packages: dnspython
# Successfully installed dnspython-2.1.0

# %%
# chargement des librairies python
import pymongo
import os
import datetime
import bson
from bson.json_util import loads, dumps, RELAXED_JSON_OPTIONS
import random
from pprint import pprint

CONNECTIONSTRING = "mongodb+srv://demo_user:mongodb@demo.mfctp.mongodb.net/iot_demo?retryWrites=true&w=majority"

# Establish Database Connection
client = pymongo.MongoClient(CONNECTIONSTRING)
db = client.iot_demo

# Clean out the tables
# Commented to get daily aggregation example
#db.iot_PT1M.drop()
#db.iot_PT5M.drop()
#db.iot_PT1H.drop()
#db.iot_PT1D.drop()

# Create Indexes in the pre aggregation collections
print(db.iot_PT1M.create_index([("device", pymongo.ASCENDING), ("ts", pymongo.ASCENDING)], unique=True))
print(db.iot_PT5M.create_index([("device", pymongo.ASCENDING), ("ts", pymongo.ASCENDING)], unique=True))
print(db.iot_PT1H.create_index([("device", pymongo.ASCENDING), ("ts", pymongo.ASCENDING)], unique=True))
print(db.iot_PT1D.create_index([("device", pymongo.ASCENDING), ("ts", pymongo.ASCENDING)], unique=True))
# Out:
# device_1_ts_1
# device_1_ts_1
# device_1_ts_1
# device_1_ts_1

# %% [markdown]
# Insérons maintenant quelques données:

# %%
BUCKET_SIZE = 50
CNT_MEASUREMENTS = 100000
STATUS = [ 'operating', 'waiting', 'idle', 'failure' ]

def prepare_collections():
    db.iot.drop()
    # Index pour les buckes ouverts par device
    db.iot.create_index([('device', 1), ('cnt', 1), ('max_ts', 1)], partialFilterExpression={'cnt': { '$lt': BUCKET_SIZE } } )
    # Index pour les requêtes par device et par plage de temps
    db.iot.create_index([('device', 1), ('max_ts', 1), ('min_ts', 1)])

def write_batch(ls_batch, collection):
    try:
        result = collection.bulk_write(ls_batch)
        return result
    except pymongo.errors.BulkWriteError as bwe:
        pprint(bwe.details)
        return None

def ingest_data():
    ts = datetime.datetime.now()

    cnt = 0
    ls_batch = []
    while cnt < CNT_MEASUREMENTS: 
        # Plus one second
        ts = ts + datetime.timedelta(0,1)
        m = {
            'ts': ts,
            'temperature': random.randint(0,100),
            'rpm': random.randint(0,2500),
            'status': random.choice(STATUS)
        }
        ls_batch.append(
            pymongo.UpdateOne({
                'device': 4711,
                'max_ts': { '$lte': ts },
                'cnt': { '$lt': BUCKET_SIZE }
            },
            {
                '$push': { 'm': m },
                '$max': { 'max_ts': ts },
                '$min': { 'min_ts': ts },
                '$inc': { 'cnt': 1 }
            },
            upsert=True ))

        cnt = cnt + 1
        if cnt % 150 == 0:
            result = write_batch(ls_batch, db.iot)
            if result != None:
                print ('inserted %s records' % (cnt) )
            ls_batch = []
            
    result = write_batch(ls_batch, db.iot)
    if result != None:
        print ('inserted %s records' % (cnt) )
    ls_batch = []
    
prepare_collections()
ingest_data()
# Out:
# inserted 150 records
# inserted 300 records
# inserted 450 records
# inserted 600 records
# inserted 750 records
# inserted 900 records
# inserted 1050 records
# inserted 1200 records
# inserted 1350 records
# inserted 1500 records
# inserted 1650 records
# inserted 1800 records
# inserted 1950 records
# inserted 2100 records
# inserted 2250 records
# inserted 2400 records
# inserted 2550 records
# inserted 2700 records
# inserted 2850 records
# inserted 3000 records
# inserted 3150 records
# inserted 3300 records
# inserted 3450 records
# inserted 3600 records
# inserted 3750 records
# inserted 3900 records
# inserted 4050 records
# inserted 4200 records
# inserted 4350 records
# inserted 4500 records
# inserted 4650 records
# inserted 4800 records
# inserted 4950 records
# inserted 5100 records
# inserted 5250 records
# inserted 5400 records
# inserted 5550 records
# inserted 5700 records
# inserted 5850 records
# inserted 6000 records
# inserted 6150 records
# inserted 6300 records
# inserted 6450 records
# inserted 6600 records
# inserted 6750 records
# inserted 6900 records
# inserted 7050 records
# inserted 7200 records
# inserted 7350 records
# inserted 7500 records
# inserted 7650 records
# inserted 7800 records
# inserted 7950 records
# inserted 8100 records
# inserted 8250 records
# inserted 8400 records
# inserted 8550 records
# inserted 8700 records
# inserted 8850 records
# inserted 9000 records
# inserted 9150 records
# inserted 9300 records
# inserted 9450 records
# inserted 9600 records
# inserted 9750 records
# inserted 9900 records
# inserted 10050 records
# inserted 10200 records
# inserted 10350 records
# inserted 10500 records
# inserted 10650 records
# inserted 10800 records
# inserted 10950 records
# inserted 11100 records
# inserted 11250 records
# inserted 11400 records
# inserted 11550 records
# inserted 11700 records
# inserted 11850 records
# inserted 12000 records
# inserted 12150 records
# inserted 12300 records
# inserted 12450 records
# inserted 12600 records
# inserted 12750 records
# inserted 12900 records
# inserted 13050 records
# inserted 13200 records
# inserted 13350 records
# inserted 13500 records
# inserted 13650 records
# inserted 13800 records
# inserted 13950 records
# inserted 14100 records
# inserted 14250 records
# inserted 14400 records
# inserted 14550 records
# inserted 14700 records
# inserted 14850 records
# inserted 15000 records
# inserted 15150 records
# inserted 15300 records
# inserted 15450 records
# inserted 15600 records
# inserted 15750 records
# inserted 15900 records
# inserted 16050 records
# inserted 16200 records
# inserted 16350 records
# inserted 16500 records
# inserted 16650 records
# inserted 16800 records
# inserted 16950 records
# inserted 17100 records
# inserted 17250 records
# inserted 17400 records
# inserted 17550 records
# inserted 17700 records
# inserted 17850 records
# inserted 18000 records
# inserted 18150 records
# inserted 18300 records
# inserted 18450 records
# inserted 18600 records
# inserted 18750 records
# inserted 18900 records
# inserted 19050 records
# inserted 19200 records
# inserted 19350 records
# inserted 19500 records
# inserted 19650 records
# inserted 19800 records
# inserted 19950 records
# inserted 20100 records
# inserted 20250 records
# inserted 20400 records
# inserted 20550 records
# inserted 20700 records
# inserted 20850 records
# inserted 21000 records
# inserted 21150 records
# inserted 21300 records
# inserted 21450 records
# inserted 21600 records
# inserted 21750 records
# inserted 21900 records
# inserted 22050 records
# inserted 22200 records
# inserted 22350 records
# inserted 22500 records
# inserted 22650 records
# inserted 22800 records
# inserted 22950 records
# inserted 23100 records
# inserted 23250 records
# inserted 23400 records
# inserted 23550 records
# inserted 23700 records
# inserted 23850 records
# inserted 24000 records
# inserted 24150 records
# inserted 24300 records
# inserted 24450 records
# inserted 24600 records
# inserted 24750 records
# inserted 24900 records
# inserted 25050 records
# inserted 25200 records
# inserted 25350 records
# inserted 25500 records
# inserted 25650 records
# inserted 25800 records
# inserted 25950 records
# inserted 26100 records
# inserted 26250 records
# inserted 26400 records
# inserted 26550 records
# inserted 26700 records
# inserted 26850 records
# inserted 27000 records
# inserted 27150 records
# inserted 27300 records
# inserted 27450 records
# inserted 27600 records
# inserted 27750 records
# inserted 27900 records
# inserted 28050 records
# inserted 28200 records
# inserted 28350 records
# inserted 28500 records
# inserted 28650 records
# inserted 28800 records
# inserted 28950 records
# inserted 29100 records
# inserted 29250 records
# inserted 29400 records
# inserted 29550 records
# inserted 29700 records
# inserted 29850 records
# inserted 30000 records
# inserted 30150 records
# inserted 30300 records
# inserted 30450 records
# inserted 30600 records
# inserted 30750 records
# inserted 30900 records
# inserted 31050 records
# inserted 31200 records
# inserted 31350 records
# inserted 31500 records
# inserted 31650 records
# inserted 31800 records
# inserted 31950 records
# inserted 32100 records
# inserted 32250 records
# inserted 32400 records
# inserted 32550 records
# inserted 32700 records
# inserted 32850 records
# inserted 33000 records
# inserted 33150 records
# inserted 33300 records
# inserted 33450 records
# inserted 33600 records
# inserted 33750 records
# inserted 33900 records
# inserted 34050 records
# inserted 34200 records
# inserted 34350 records
# inserted 34500 records
# inserted 34650 records
# inserted 34800 records
# inserted 34950 records
# inserted 35100 records
# inserted 35250 records
# inserted 35400 records
# inserted 35550 records
# inserted 35700 records
# inserted 35850 records
# inserted 36000 records
# inserted 36150 records
# inserted 36300 records
# inserted 36450 records
# inserted 36600 records
# inserted 36750 records
# inserted 36900 records
# inserted 37050 records
# inserted 37200 records
# inserted 37350 records
# inserted 37500 records
# inserted 37650 records
# inserted 37800 records
# inserted 37950 records
# inserted 38100 records
# inserted 38250 records
# inserted 38400 records
# inserted 38550 records
# inserted 38700 records
# inserted 38850 records
# inserted 39000 records
# inserted 39150 records
# inserted 39300 records
# inserted 39450 records
# inserted 39600 records
# inserted 39750 records
# inserted 39900 records
# inserted 40050 records
# inserted 40200 records
# inserted 40350 records
# inserted 40500 records
# inserted 40650 records
# inserted 40800 records
# inserted 40950 records
# inserted 41100 records
# inserted 41250 records
# inserted 41400 records
# inserted 41550 records
# inserted 41700 records
# inserted 41850 records
# inserted 42000 records
# inserted 42150 records
# inserted 42300 records
# inserted 42450 records
# inserted 42600 records
# inserted 42750 records
# inserted 42900 records
# inserted 43050 records
# inserted 43200 records
# inserted 43350 records
# inserted 43500 records
# inserted 43650 records
# inserted 43800 records
# inserted 43950 records
# inserted 44100 records
# inserted 44250 records
# inserted 44400 records
# inserted 44550 records
# inserted 44700 records
# inserted 44850 records
# inserted 45000 records
# inserted 45150 records
# inserted 45300 records
# inserted 45450 records
# inserted 45600 records
# inserted 45750 records
# inserted 45900 records
# inserted 46050 records
# inserted 46200 records
# inserted 46350 records
# inserted 46500 records
# inserted 46650 records
# inserted 46800 records
# inserted 46950 records
# inserted 47100 records
# inserted 47250 records
# inserted 47400 records
# inserted 47550 records
# inserted 47700 records
# inserted 47850 records
# inserted 48000 records
# inserted 48150 records
# inserted 48300 records
# inserted 48450 records
# inserted 48600 records
# inserted 48750 records
# inserted 48900 records
# inserted 49050 records
# inserted 49200 records
# inserted 49350 records
# inserted 49500 records
# inserted 49650 records
# inserted 49800 records
# inserted 49950 records
# inserted 50100 records
# inserted 50250 records
# inserted 50400 records
# inserted 50550 records
# inserted 50700 records
# inserted 50850 records
# inserted 51000 records
# inserted 51150 records
# inserted 51300 records
# inserted 51450 records
# inserted 51600 records
# inserted 51750 records
# inserted 51900 records
# inserted 52050 records
# inserted 52200 records
# inserted 52350 records
# inserted 52500 records
# inserted 52650 records
# inserted 52800 records
# inserted 52950 records
# inserted 53100 records
# inserted 53250 records
# inserted 53400 records
# inserted 53550 records
# inserted 53700 records
# inserted 53850 records
# inserted 54000 records
# inserted 54150 records
# inserted 54300 records
# inserted 54450 records
# inserted 54600 records
# inserted 54750 records
# inserted 54900 records
# inserted 55050 records
# inserted 55200 records
# inserted 55350 records
# inserted 55500 records
# inserted 55650 records
# inserted 55800 records
# inserted 55950 records
# inserted 56100 records
# inserted 56250 records
# inserted 56400 records
# inserted 56550 records
# inserted 56700 records
# inserted 56850 records
# inserted 57000 records
# inserted 57150 records
# inserted 57300 records
# inserted 57450 records
# inserted 57600 records
# inserted 57750 records
# inserted 57900 records
# inserted 58050 records
# inserted 58200 records
# inserted 58350 records
# inserted 58500 records
# inserted 58650 records
# inserted 58800 records
# inserted 58950 records
# inserted 59100 records
# inserted 59250 records
# inserted 59400 records
# inserted 59550 records
# inserted 59700 records
# inserted 59850 records
# inserted 60000 records
# inserted 60150 records
# inserted 60300 records
# inserted 60450 records
# inserted 60600 records
# inserted 60750 records
# inserted 60900 records
# inserted 61050 records
# inserted 61200 records
# inserted 61350 records
# inserted 61500 records
# inserted 61650 records
# inserted 61800 records
# inserted 61950 records
# inserted 62100 records
# inserted 62250 records
# inserted 62400 records
# inserted 62550 records
# inserted 62700 records
# inserted 62850 records
# inserted 63000 records
# inserted 63150 records
# inserted 63300 records
# inserted 63450 records
# inserted 63600 records
# inserted 63750 records
# inserted 63900 records
# inserted 64050 records
# inserted 64200 records
# inserted 64350 records
# inserted 64500 records
# inserted 64650 records
# inserted 64800 records
# inserted 64950 records
# inserted 65100 records
# inserted 65250 records
# inserted 65400 records
# inserted 65550 records
# inserted 65700 records
# inserted 65850 records
# inserted 66000 records
# inserted 66150 records
# inserted 66300 records
# inserted 66450 records
# inserted 66600 records
# inserted 66750 records
# inserted 66900 records
# inserted 67050 records
# inserted 67200 records
# inserted 67350 records
# inserted 67500 records
# inserted 67650 records
# inserted 67800 records
# inserted 67950 records
# inserted 68100 records
# inserted 68250 records
# inserted 68400 records
# inserted 68550 records
# inserted 68700 records
# inserted 68850 records
# inserted 69000 records
# inserted 69150 records
# inserted 69300 records
# inserted 69450 records
# inserted 69600 records
# inserted 69750 records
# inserted 69900 records
# inserted 70050 records
# inserted 70200 records
# inserted 70350 records
# inserted 70500 records
# inserted 70650 records
# inserted 70800 records
# inserted 70950 records
# inserted 71100 records
# inserted 71250 records
# inserted 71400 records
# inserted 71550 records
# inserted 71700 records
# inserted 71850 records
# inserted 72000 records
# inserted 72150 records
# inserted 72300 records
# inserted 72450 records
# inserted 72600 records
# inserted 72750 records
# inserted 72900 records
# inserted 73050 records
# inserted 73200 records
# inserted 73350 records
# inserted 73500 records
# inserted 73650 records
# inserted 73800 records
# inserted 73950 records
# inserted 74100 records
# inserted 74250 records
# inserted 74400 records
# inserted 74550 records
# inserted 74700 records
# inserted 74850 records
# inserted 75000 records
# inserted 75150 records
# inserted 75300 records
# inserted 75450 records
# inserted 75600 records
# inserted 75750 records
# inserted 75900 records
# inserted 76050 records
# inserted 76200 records
# inserted 76350 records
# inserted 76500 records
# inserted 76650 records
# inserted 76800 records
# inserted 76950 records
# inserted 77100 records
# inserted 77250 records
# inserted 77400 records
# inserted 77550 records
# inserted 77700 records
# inserted 77850 records
# inserted 78000 records
# inserted 78150 records
# inserted 78300 records
# inserted 78450 records
# inserted 78600 records
# inserted 78750 records
# inserted 78900 records
# inserted 79050 records
# inserted 79200 records
# inserted 79350 records
# inserted 79500 records
# inserted 79650 records
# inserted 79800 records
# inserted 79950 records
# inserted 80100 records
# inserted 80250 records
# inserted 80400 records
# inserted 80550 records
# inserted 80700 records
# inserted 80850 records
# inserted 81000 records
# inserted 81150 records
# inserted 81300 records
# inserted 81450 records
# inserted 81600 records
# inserted 81750 records
# inserted 81900 records
# inserted 82050 records
# inserted 82200 records
# inserted 82350 records
# inserted 82500 records
# inserted 82650 records
# inserted 82800 records
# inserted 82950 records
# inserted 83100 records
# inserted 83250 records
# inserted 83400 records
# inserted 83550 records
# inserted 83700 records
# inserted 83850 records
# inserted 84000 records
# inserted 84150 records
# inserted 84300 records
# inserted 84450 records
# inserted 84600 records
# inserted 84750 records
# inserted 84900 records
# inserted 85050 records
# inserted 85200 records
# inserted 85350 records
# inserted 85500 records
# inserted 85650 records
# inserted 85800 records
# inserted 85950 records
# inserted 86100 records
# inserted 86250 records
# inserted 86400 records
# inserted 86550 records
# inserted 86700 records
# inserted 86850 records
# inserted 87000 records
# inserted 87150 records
# inserted 87300 records
# inserted 87450 records
# inserted 87600 records
# inserted 87750 records
# inserted 87900 records
# inserted 88050 records
# inserted 88200 records
# inserted 88350 records
# inserted 88500 records
# inserted 88650 records
# inserted 88800 records
# inserted 88950 records
# inserted 89100 records
# inserted 89250 records
# inserted 89400 records
# inserted 89550 records
# inserted 89700 records
# inserted 89850 records
# inserted 90000 records
# inserted 90150 records
# inserted 90300 records
# inserted 90450 records
# inserted 90600 records
# inserted 90750 records
# inserted 90900 records
# inserted 91050 records
# inserted 91200 records
# inserted 91350 records
# inserted 91500 records
# inserted 91650 records
# inserted 91800 records
# inserted 91950 records
# inserted 92100 records
# inserted 92250 records
# inserted 92400 records
# inserted 92550 records
# inserted 92700 records
# inserted 92850 records
# inserted 93000 records
# inserted 93150 records
# inserted 93300 records
# inserted 93450 records
# inserted 93600 records
# inserted 93750 records
# inserted 93900 records
# inserted 94050 records
# inserted 94200 records
# inserted 94350 records
# inserted 94500 records
# inserted 94650 records
# inserted 94800 records
# inserted 94950 records
# inserted 95100 records
# inserted 95250 records
# inserted 95400 records
# inserted 95550 records
# inserted 95700 records
# inserted 95850 records
# inserted 96000 records
# inserted 96150 records
# inserted 96300 records
# inserted 96450 records
# inserted 96600 records
# inserted 96750 records
# inserted 96900 records
# inserted 97050 records
# inserted 97200 records
# inserted 97350 records
# inserted 97500 records
# inserted 97650 records
# inserted 97800 records
# inserted 97950 records
# inserted 98100 records
# inserted 98250 records
# inserted 98400 records
# inserted 98550 records
# inserted 98700 records
# inserted 98850 records
# inserted 99000 records
# inserted 99150 records
# inserted 99300 records
# inserted 99450 records
# inserted 99600 records
# inserted 99750 records
# inserted 99900 records
# inserted 100000 records

# %% [markdown]
# ## Aggregation des données à la minute
# Ce pippeline d'aggrégation permet d'agréger les valeurs avec un document par device et par minute.

# %%
db.iot.aggregate([
{ "$unwind": { "path": "$m" }}, 
{ "$sort": { "m.ts": 1 }}, 
{ "$group": {
  "_id": {
    "device": "$device",
    "year": { "$year": '$m.ts' },
    "month": { "$month": '$m.ts' },
    "day": { "$dayOfMonth": '$m.ts' },
    "hour": { "$hour": '$m.ts' },
    "minute": { "$minute": '$m.ts' }
  },
  "temperature_avg": { "$avg": "$m.temperature" },
  "temperature_min": { "$min": "$m.temperature" },
  "temperature_max": { "$max": "$m.temperature" },
  "temperature_first": { "$first": "$m.temperature" },
  "temperature_last": { "$last": "$m.temperature" },
  "rpm_avg": { "$avg": "$m.rpm" },
  "rpm_min": { "$min": "$m.rpm" },
  "rpm_max": { "$max": "$m.rpm" },
  "rpm_first": { "$first": "$m.rpm" },
  "rpm_last": { "$last": "$m.rpm" },  
  "status_first": { "$first": "$m.status" },
  "status_last": { "$last": "$m.status" },
}}, 
{ "$addFields": {
  "device": '$_id.device',
  "ts": {
    "$dateFromParts": {
      "year": '$_id.year',
      "month": '$_id.month',
      "day": '$_id.day',
      "hour": '$_id.hour',
      "minute": '$_id.minute'
    }
  }
}}, 
{ "$project": { "_id": 0 }}, 
{ "$merge": {
  "into": 'iot_PT1M',
  "on": ['device', 'ts']
}}
], allowDiskUse = True)

# %% [markdown]
# Affichons maintenant un document issu de cette aggrégation

# %%
result = db.iot_PT1M.find_one()

pprint(result)
# Out:
# {'_id': ObjectId('5fd08d734a618ba100079d60'),
#  'device': 4711,
#  'rpm_avg': 1388.1333333333334,
#  'rpm_first': 1130,
#  'rpm_last': 226,
#  'rpm_max': 2482,
#  'rpm_min': 74,
#  'status_first': 'failure',
#  'status_last': 'idle',
#  'temperature_avg': 48.93333333333333,
#  'temperature_first': 24,
#  'temperature_last': 19,
#  'temperature_max': 100,
#  'temperature_min': 0,
#  'ts': datetime.datetime(2020, 12, 9, 17, 32)}

# %% [markdown]
# Aggrégons maintenant les données à 5 minutes à partir de l'agrégation précédente.

# %%
db.iot_PT1M.aggregate([
# s'assurer de l'utilisation de l'index via cette étape de tri
{ "$sort": {
  'device':1,
  'ts': 1
}}, 
{"$group": {
  "_id": {
    "device": "$device",
    "year": { "$year": '$ts' },
    "month": { "$month": '$ts' },
    "day": { "$dayOfMonth": '$ts' },
    "hour": { "$hour": '$ts' },
    "minute": { "$subtract": [
        { "$minute": '$ts' },
        { "$mod": [ { "$minute": '$ts' }, 5 ] }
      ] 
   }
  },
  "temperature_avg": { "$avg": '$temperature_avg' },
  "temperature_min": { "$min": '$temperature_min' },
  "temperature_max": { "$max": '$temperature_max' },
  "temperature_first": { "$first": '$temperature_first' },
  "temperature_last": { "$last": '$temperature_last' },
  "rpm_avg": { "$avg": '$rpm_avg' },
  "rpm_min": { "$min": '$rpm_min' },
  "rpm_max": { "$max": '$rpm_max' },
  "rpm_first": { "$first": '$rpm_first' },
  "rpm_last": { "$last": '$rpm_last' },
  "status_first": { "$first": '$status_first' },
  "status_last": { "$last": '$status_last' }
}}, 
{ "$addFields": {
  "device": '$_id.device',
  "ts": {
    "$dateFromParts": {
      "year": '$_id.year',
      "month": '$_id.month',
      "day": '$_id.day',
      "hour": '$_id.hour',
      "minute": '$_id.minute'
    }
  }
}}, 
{ "$project": { "_id": 0 }}, 
{ "$merge": {
  "into": 'iot_PT5M',
  "on": [ 'device', 'ts' ]
}}])

# %% [markdown]
# Affichons un exemple de document.

# %%
result = db.iot_PT5M.find_one()

pprint(result)
# Out:
# {'_id': ObjectId('5fd090674a618ba10007e020'),
#  'device': 4711,
#  'rpm_avg': 1280.4866666666667,
#  'rpm_first': 1738,
#  'rpm_last': 158,
#  'rpm_max': 2495,
#  'rpm_min': 20,
#  'status_first': 'waiting',
#  'status_last': 'idle',
#  'temperature_avg': 50.61,
#  'temperature_first': 49,
#  'temperature_last': 31,
#  'temperature_max': 99,
#  'temperature_min': 0,
#  'ts': datetime.datetime(2020, 12, 9, 14, 5)}

# %% [markdown]
# La seule modification dans les pipelines d'aggrégation qui va maintenant être effectuée va être au niveau de l'étape $group.
#
# Agrégeons les données à l'heure.

# %%
db.iot_PT5M.aggregate([
# S"assurer de l'utilisation de l'index via l'utilisation de cette étape de tri
{ "$sort": {
  'device':1,
  'ts': 1
}},  
{"$group": {
  "_id": {
    "device": "$device",
    "year": { "$year": '$ts' },
    "month": { "$month": '$ts' },
    "day": { "$dayOfMonth": '$ts' },
    "hour": { "$hour": '$ts' }
  },
  "temperature_avg": { "$avg": '$temperature_avg' },
  "temperature_min": { "$min": '$temperature_min' },
  "temperature_max": { "$max": '$temperature_max' },
  "temperature_first": { "$first": '$temperature_first' },
  "temperature_last": { "$last": '$temperature_last' },
  "rpm_avg": { "$avg": '$rpm_avg' },
  "rpm_min": { "$min": '$rpm_min' },
  "rpm_max": { "$max": '$rpm_max' },
  "rpm_first": { "$first": '$rpm_first' },
  "rpm_last": { "$last": '$rpm_last' },
  "status_first": { "$first": '$status_first' },
  "status_last": { "$last": '$status_last' }
}},
{ "$addFields": {
  "device": '$_id.device',
  "ts": {
    "$dateFromParts": {
      "year": '$_id.year',
      "month": '$_id.month',
      "day": '$_id.day',
      "hour": '$_id.hour'
    }
  }
}}, 
{ "$project": { "_id": 0 }}, 
{ "$merge": {
  "into": 'iot_PT1H',
  "on": [ 'device', 'ts' ]
}}])

# %% [markdown]
# Affichons un exemple de document.

# %%
result = db.iot_PT1H.find_one()

pprint(result)
# Out:
# {'_id': ObjectId('5fd090bb4a618ba10007e5c4'),
#  'device': 4711,
#  'rpm_avg': 1254.3269444444445,
#  'rpm_first': 1554,
#  'rpm_last': 555,
#  'rpm_max': 2500,
#  'rpm_min': 0,
#  'status_first': 'idle',
#  'status_last': 'idle',
#  'temperature_avg': 50.092222222222226,
#  'temperature_first': 73,
#  'temperature_last': 40,
#  'temperature_max': 100,
#  'temperature_min': 0,
#  'ts': datetime.datetime(2020, 12, 9, 12, 0)}

# %% [markdown]
# Aggrégation sur 1 journée.

# %%
db.iot_PT1H.aggregate([
# S'assurer de l'utilisation de l'index va cette étape de tri
{ "$sort": {
  'device':1,
  'ts': 1
}}, 
{"$group": {
  "_id": {
    "device": "$device",
    "year": { "$year": '$ts' },
    "month": { "$month": '$ts' },
    "day": { "$dayOfMonth": '$ts' }
  },
  "temperature_avg": { "$avg": '$temperature_avg' },
  "temperature_min": { "$min": '$temperature_min' },
  "temperature_max": { "$max": '$temperature_max' },
  "temperature_first": { "$first": '$temperature_first' },
  "temperature_last": { "$last": '$temperature_last' },
  "rpm_avg": { "$avg": '$rpm_avg' },
  "rpm_min": { "$min": '$rpm_min' },
  "rpm_max": { "$max": '$rpm_max' },
  "rpm_first": { "$first": '$rpm_first' },
  "rpm_last": { "$last": '$rpm_last' },
  "status_first": { "$first": '$status_first' },
  "status_last": { "$last": '$status_last' }
}},
{ "$addFields": {
  "device": '$_id.device',
  "ts": {
    "$dateFromParts": {
      "year": '$_id.year',
      "month": '$_id.month',
      "day": '$_id.day'
    }
  }
}}, 
{ "$project": { "_id": 0 }}, 
{ "$merge": {
  "into": 'iot_PT1D',
  "on": [ 'device', 'ts' ]
}}])

# %% [markdown]
# Affichage d'un document.

# %%
result = db.iot_PT1D.find_one()

pprint(result)
# Out:
# {'_id': ObjectId('5fd22d5a4a618ba1005ce3dd'),
#  'device': 4711,
#  'rpm_avg': 1253.56508005698,
#  'rpm_first': 80,
#  'rpm_last': 963,
#  'rpm_max': 2500,
#  'rpm_min': 0,
#  'status_first': 'operating',
#  'status_last': 'idle',
#  'temperature_avg': 50.1075623931624,
#  'temperature_first': 60,
#  'temperature_last': 40,
#  'temperature_max': 100,
#  'temperature_min': 0,
#  'ts': datetime.datetime(2020, 12, 9, 0, 0)}
